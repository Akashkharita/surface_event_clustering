# %%
import pandas as pd

# %%
pd.read_csv('../src/IRIS_DMC_esecEventsDb.txt', sep = '|')
# Out:
#      areaSource  areaSourceHigh  areaSourceLow   areaTotal  associationId  \
# 0           NaN             NaN            NaN         NaN             22
# 1      100000.0             NaN            NaN   1600000.0            273
# 2           NaN             NaN            NaN         NaN            218
# 3      111000.0             NaN            NaN   1130000.0            127
# 4           NaN             NaN            NaN  10000000.0            285
# ..          ...             ...            ...         ...            ...
# 285    310000.0        520000.0       200000.0   7900000.0             19
# 286   3500000.0             NaN            NaN         NaN            275
# 287    130000.0        160000.0        84000.0   3000000.0            188
# 288         NaN             NaN            NaN         NaN            159
# 289         NaN             NaN            NaN         NaN            227
#
#                                   datlocation  depth            endtime  \
# ...
